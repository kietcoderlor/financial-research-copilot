# %% [markdown]
# # Retrieval Spot Check (P3-9)
#
# This notebook runs retrieval spot checks against `POST /retrieve`, applies heuristic labels (`Relevant`, `Partial`, `Not Relevant`), and writes `eval/retrieval_results.md`.
#
# You can tune the query set or labels later.

# %%
from eval.run_retrieval_spot_check import main

main()
